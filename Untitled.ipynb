# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline
img = np.zeros((160,320,3))
img = cv2.imread('/home/joe/CarND-Behavioral-Cloning-P3/d_first_test/IMG/center_2017_05_20_22_13_49_260.jpg')
print(type(img))
print(np.shape(img))

img = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)

x = np.random.randint(2)
h = np.random.randint(120)
print(x)
print(h)
if x ==0 :
    img[:,:,2] = np.clip(img[:,:,2], 0, 255-h)
    img[:,:,2] += h
else:
    img[:,:,2] = np.clip(img[:,:,2], 0+h, 255)
    img[:,:,2] -= h
    
img = cv2.cvtColor(img, cv2.COLOR_HSV2RGB)
#img[:,:,2] = 0

#gray = cv2.cvtColor(img[60:140], cv2.COLOR_BGR2RGB)
#gray = img[65:140,:,2]
#print(np.shape(gray))

plt.imshow(img[:,:,:], 'hsv')
print(type(img))
print(np.shape(img))

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline
img = np.zeros((160,320,3))
img = cv2.imread('/home/joe/CarND-Behavioral-Cloning-P3/d_first_test/IMG/center_2017_05_20_22_13_49_260.jpg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
img[:,:80,:] = 150
plt.imshow(img[:,:,:], 'hsv')

# %%
dst = cv2.Sobel(img, cv2.CV_64F, 0, 1)

dst[:,:,0] = cv2.Sobel(img[:,:,0], cv2.CV_64F, 0, 1)
dst[:,:,1] = cv2.Sobel(img[:,:,1], cv2.CV_64F, 0, 1)
dst[:,:,2] = cv2.Sobel(img[:,:,2], cv2.CV_64F, 0, 1)

plt.imshow(dst[:,:,2])

# %%
dst[:,:,0] = cv2.Laplacian(img[:,:,2], cv2.CV_64F, 0, 1)
plt.imshow(dst[:,:,2])

# %%
#plt.imshow(abs(dst), 'gray')
np.random.randint(3)
a = np.arange(0,9).reshape((3,3))
b = np.arange(10,19).reshape((3,3))
l = [a,b]
print(l)
print()
print(np.array(l))
print(np.array(([[1,2],[3,4]] , [[0,0],[1,1]])))
